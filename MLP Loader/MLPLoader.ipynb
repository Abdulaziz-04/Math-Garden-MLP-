# %% [markdown]
# # Imports

# %%
import numpy as np
import tensorflow.compat.v1 as tf
import tensorflow as tf2
from tensorflow.compat.v1.saved_model import load,tag_constants

# %% [markdown]
# # Constants

# %%
X_TEST_PATH = 'mnist/load_xtest.csv'
Y_TEST_PATH = 'mnist/load_ytest.csv'

# %% [markdown]
# # Load the Data

# %%
y_test = np.loadtxt(Y_TEST_PATH, delimiter=',', dtype=int)
print(f'Shape of y_test {y_test.shape}')
# Out:
# Shape of y_test (10000,)

# %%
x_test = np.loadtxt(X_TEST_PATH, delimiter=',', dtype=float)
print(f'Shape of x_test {x_test.shape}')
# Out:
# Shape of x_test (10000, 784)

# %% [markdown]
# # Create Session

# %%
graph=tf.Graph()
session=tf.Session(graph=graph)

# %% [markdown]
# # Load the Model

# %% [markdown]
# ```
# tf.compat.v1.saved_model.load(sess,
#                            [tag_constants.SERVING],
#                            EXPORT_DIR)
# ```

# %%
load(sess=session,tags=[tag_constants.SERVING],export_dir='Saved MLP Model')
# Out:
# INFO:tensorflow:Restoring parameters from Saved MLP Model\variables\variables
#       shape {
#             unknown_rank: true
#           }
#         }
#       }
#     }
#     attr {
#       key: "dtypes"
#       value {
#         list {
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#           type: DT_FLOAT
#         }
#       }
#     }
#   }
#   node {
#     name: "save/Assign"
#     op: "Assign"
#     input: "beta1_power"
#     input: "save/RestoreV2"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer1/Variable"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_1"
#     op: "Assign"
#     input: "beta2_power"
#     input: "save/RestoreV2:1"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer1/Variable"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_2"
#     op: "Assign"
#     input: "layer1/Variable"
#     input: "save/RestoreV2:2"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer1/Variable"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 784
#             }
#             dim {
#               size: 512
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_3"
#     op: "Assign"
#     input: "layer1/Variable/Adam"
#     input: "save/RestoreV2:3"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer1/Variable"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 784
#             }
#             dim {
#               size: 512
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_4"
#     op: "Assign"
#     input: "layer1/Variable/Adam_1"
#     input: "save/RestoreV2:4"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer1/Variable"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 784
#             }
#             dim {
#               size: 512
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_5"
#     op: "Assign"
#     input: "layer1/Variable_1"
#     input: "save/RestoreV2:5"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer1/Variable_1"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 512
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_6"
#     op: "Assign"
#     input: "layer1/Variable_1/Adam"
#     input: "save/RestoreV2:6"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer1/Variable_1"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 512
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_7"
#     op: "Assign"
#     input: "layer1/Variable_1/Adam_1"
#     input: "save/RestoreV2:7"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer1/Variable_1"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 512
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_8"
#     op: "Assign"
#     input: "layer2/Variable"
#     input: "save/RestoreV2:8"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer2/Variable"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 512
#             }
#             dim {
#               size: 64
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_9"
#     op: "Assign"
#     input: "layer2/Variable/Adam"
#     input: "save/RestoreV2:9"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer2/Variable"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 512
#             }
#             dim {
#               size: 64
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_10"
#     op: "Assign"
#     input: "layer2/Variable/Adam_1"
#     input: "save/RestoreV2:10"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer2/Variable"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 512
#             }
#             dim {
#               size: 64
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_11"
#     op: "Assign"
#     input: "layer2/Variable_1"
#     input: "save/RestoreV2:11"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer2/Variable_1"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 64
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_12"
#     op: "Assign"
#     input: "layer2/Variable_1/Adam"
#     input: "save/RestoreV2:12"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer2/Variable_1"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 64
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_13"
#     op: "Assign"
#     input: "layer2/Variable_1/Adam_1"
#     input: "save/RestoreV2:13"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@layer2/Variable_1"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 64
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_14"
#     op: "Assign"
#     input: "output/Variable"
#     input: "save/RestoreV2:14"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@output/Variable"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 64
#             }
#             dim {
#               size: 10
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_15"
#     op: "Assign"
#     input: "output/Variable/Adam"
#     input: "save/RestoreV2:15"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@output/Variable"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 64
#             }
#             dim {
#               size: 10
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_16"
#     op: "Assign"
#     input: "output/Variable/Adam_1"
#     input: "save/RestoreV2:16"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@output/Variable"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 64
#             }
#             dim {
#               size: 10
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_17"
#     op: "Assign"
#     input: "output/Variable_1"
#     input: "save/RestoreV2:17"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@output/Variable_1"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 10
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_18"
#     op: "Assign"
#     input: "output/Variable_1/Adam"
#     input: "save/RestoreV2:18"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@output/Variable_1"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 10
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/Assign_19"
#     op: "Assign"
#     input: "output/Variable_1/Adam_1"
#     input: "save/RestoreV2:19"
#     attr {
#       key: "T"
#       value {
#         type: DT_FLOAT
#       }
#     }
#     attr {
#       key: "_class"
#       value {
#         list {
#           s: "loc:@output/Variable_1"
#         }
#       }
#     }
#     attr {
#       key: "_output_shapes"
#       value {
#         list {
#           shape {
#             dim {
#               size: 10
#             }
#           }
#         }
#       }
#     }
#     attr {
#       key: "use_locking"
#       value {
#         b: true
#       }
#     }
#     attr {
#       key: "validate_shape"
#       value {
#         b: true
#       }
#     }
#   }
#   node {
#     name: "save/restore_shard"
#     op: "NoOp"
#     input: "^save/Assign"
#     input: "^save/Assign_1"
#     input: "^save/Assign_10"
#     input: "^save/Assign_11"
#     input: "^save/Assign_12"
#     input: "^save/Assign_13"
#     input: "^save/Assign_14"
#     input: "^save/Assign_15"
#     input: "^save/Assign_16"
#     input: "^save/Assign_17"
#     input: "^save/Assign_18"
#     input: "^save/Assign_19"
#     input: "^save/Assign_2"
#     input: "^save/Assign_3"
#     input: "^save/Assign_4"
#     input: "^save/Assign_5"
#     input: "^save/Assign_6"
#     input: "^save/Assign_7"
#     input: "^save/Assign_8"
#     input: "^save/Assign_9"
#   }
#   node {
#     name: "save/restore_all"
#     op: "NoOp"
#     input: "^save/restore_shard"
#   }
#   library {
#   }
#   versions {
#     producer: 561
#   }
# }
# saver_def {
#   filename_tensor_name: "save/Const:0"
#   save_tensor_name: "save/Identity:0"
#   restore_op_name: "save/restore_all"
#   max_to_keep: 5
#   sharded: true
#   keep_checkpoint_every_n_hours: 10000.0
#   version: V2
# }
# collection_def {
#   key: "summaries"
#   value {
#     node_list {
#       value: "performance/accuracy:0"
#       value: "performance/loss:0"
#       value: "image_input:0"
#     }
#   }
# }
# collection_def {
#   key: "train_op"
#   value {
#     node_list {
#       value: "Adam"
#     }
#   }
# }
# collection_def {
#   key: "trainable_variables"
#   value {
#     bytes_list {
#       value: "\n\021layer1/Variable:0\022\026layer1/Variable/Assign\032\026layer1/Variable/read:02\031layer1/truncated_normal:08\001"
#       value: "\n\023layer1/Variable_1:0\022\030layer1/Variable_1/Assign\032\030layer1/Variable_1/read:02\016layer1/Const:08\001"
#       value: "\n\021layer2/Variable:0\022\026layer2/Variable/Assign\032\026layer2/Variable/read:02\031layer2/truncated_normal:08\001"
#       value: "\n\023layer2/Variable_1:0\022\030layer2/Variable_1/Assign\032\030layer2/Variable_1/read:02\016layer2/Const:08\001"
#       value: "\n\021output/Variable:0\022\026output/Variable/Assign\032\026output/Variable/read:02\031output/truncated_normal:08\001"
#       value: "\n\023output/Variable_1:0\022\030output/Variable_1/Assign\032\030output/Variable_1/read:02\016output/Const:08\001"
#     }
#   }
# }
# collection_def {
#   key: "variables"
#   value {
#     bytes_list {
#       value: "\n\021layer1/Variable:0\022\026layer1/Variable/Assign\032\026layer1/Variable/read:02\031layer1/truncated_normal:08\001"
#       value: "\n\023layer1/Variable_1:0\022\030layer1/Variable_1/Assign\032\030layer1/Variable_1/read:02\016layer1/Const:08\001"
#       value: "\n\021layer2/Variable:0\022\026layer2/Variable/Assign\032\026layer2/Variable/read:02\031layer2/truncated_normal:08\001"
#       value: "\n\023layer2/Variable_1:0\022\030layer2/Variable_1/Assign\032\030layer2/Variable_1/read:02\016layer2/Const:08\001"
#       value: "\n\021output/Variable:0\022\026output/Variable/Assign\032\026output/Variable/read:02\031output/truncated_normal:08\001"
#       value: "\n\023output/Variable_1:0\022\030output/Variable_1/Assign\032\030output/Variable_1/read:02\016output/Const:08\001"
#       value: "\n\rbeta1_power:0\022\022beta1_power/Assign\032\022beta1_power/read:02\033beta1_power/initial_value:0"
#       value: "\n\rbeta2_power:0\022\022beta2_power/Assign\032\022beta2_power/read:02\033beta2_power/initial_value:0"
#       value: "\n\026layer1/Variable/Adam:0\022\033layer1/Variable/Adam/Assign\032\033layer1/Variable/Adam/read:02(layer1/Variable/Adam/Initializer/zeros:0"
#       value: "\n\030layer1/Variable/Adam_1:0\022\035layer1/Variable/Adam_1/Assign\032\035layer1/Variable/Adam_1/read:02*layer1/Variable/Adam_1/Initializer/zeros:0"
#       value: "\n\030layer1/Variable_1/Adam:0\022\035layer1/Variable_1/Adam/Assign\032\035layer1/Variable_1/Adam/read:02*layer1/Variable_1/Adam/Initializer/zeros:0"
#       value: "\n\032layer1/Variable_1/Adam_1:0\022\037layer1/Variable_1/Adam_1/Assign\032\037layer1/Variable_1/Adam_1/read:02,layer1/Variable_1/Adam_1/Initializer/zeros:0"
#       value: "\n\026layer2/Variable/Adam:0\022\033layer2/Variable/Adam/Assign\032\033layer2/Variable/Adam/read:02(layer2/Variable/Adam/Initializer/zeros:0"
#       value: "\n\030layer2/Variable/Adam_1:0\022\035layer2/Variable/Adam_1/Assign\032\035layer2/Variable/Adam_1/read:02*layer2/Variable/Adam_1/Initializer/zeros:0"
#       value: "\n\030layer2/Variable_1/Adam:0\022\035layer2/Variable_1/Adam/Assign\032\035layer2/Variable_1/Adam/read:02*layer2/Variable_1/Adam/Initializer/zeros:0"
#       value: "\n\032layer2/Variable_1/Adam_1:0\022\037layer2/Variable_1/Adam_1/Assign\032\037layer2/Variable_1/Adam_1/read:02,layer2/Variable_1/Adam_1/Initializer/zeros:0"
#       value: "\n\026output/Variable/Adam:0\022\033output/Variable/Adam/Assign\032\033output/Variable/Adam/read:02(output/Variable/Adam/Initializer/zeros:0"
#       value: "\n\030output/Variable/Adam_1:0\022\035output/Variable/Adam_1/Assign\032\035output/Variable/Adam_1/read:02*output/Variable/Adam_1/Initializer/zeros:0"
#       value: "\n\030output/Variable_1/Adam:0\022\035output/Variable_1/Adam/Assign\032\035output/Variable_1/Adam/read:02*output/Variable_1/Adam/Initializer/zeros:0"
#       value: "\n\032output/Variable_1/Adam_1:0\022\037output/Variable_1/Adam_1/Assign\032\037output/Variable_1/Adam_1/read:02,output/Variable_1/Adam_1/Initializer/zeros:0"
#     }
#   }
# }
# signature_def {
#   key: "serving_default"
#   value {
#     inputs {
#       key: "input-attr"
#       value {
#         name: "input-attr:0"
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: -1
#           }
#           dim {
#             size: 784
#           }
#         }
#       }
#     }
#     outputs {
#       key: "accuracy_calc/output-attr"
#       value {
#         name: "accuracy_calc/output-attr:0"
#         dtype: DT_INT64
#         tensor_shape {
#           dim {
#             size: -1
#           }
#         }
#       }
#     }
#     method_name: "tensorflow/serving/predict"
#   }
# }

# %%
input=graph.get_tensor_by_name('input-attr:0')
output=graph.get_tensor_by_name('accuracy_calc/output-attr:0')

# %% [markdown]
# # Run Session & Make Prediction

# %%
prediction=session.run(fetches=output,feed_dict={input:x_test})

# %% [markdown]
# # Check Results

# %%
correct_results=np.equal(prediction,y_test)
sum(correct_results)/len(y_test)*100
# Out:
# 97.09

# %% [markdown]
# # Cleanup

# %%
session.close()
tf.reset_default_graph()
